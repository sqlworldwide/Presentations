# %% [markdown]
# # Analyzing Azure Monitor Log data in Azure Data Studio

# %% [markdown]
# ## Abstract
#
# How do you consume the data once you enable event logging (auditing and diagnostic) for the Azure SQL database? How do you find anomalies to alert on, establish a baseline, look at trends?
#
# In this 100% demo session, I will show you kql magic, kql kernel, and the recently released Azure Monitor Logs extension for Azure Data Studio to consume event logs of the Azure SQL database.

# %% [markdown]
# ## SQLBits 2022
#
# ## March 10, 2022
#
# ![SQLBits 2022 | Get Tickets to the Data Conference](https://arcade.sqlbits.com/wp-content/uploads/2021/12/SQLBits_LOGO001.png)
#
# Thank you to our sponsors!!
#
# ![](attachment:image.png)

# %% [markdown]
# - Kusto Query Language
#     - Azure Monitor Data
#     - Azure Data Explorer
#     - ApplicationInsights
# - Azure Monitor Log data
#     - How do you collect diagonstic data from Azure SQL Database?
#     - What format the data is?
#     - How do you consume natively in Portal (Demo)?
# - Azure Data Studio (Demo)
#     - Kqlmagic
#     - Kusto (KQL) extension for Azure Data Studio
#     - Azure Monitor Logs extension for Azure Data Studio

# %% [markdown]
# # DEMO
#
# - Setup (3 files)
# - Demokqlmagic.ipynb
# - DemokqlExtension.ipynb
# - DemoAzureMonitorLogExtension.ipynb

# %% [markdown]
# ### Refernece:
# - [Monitoring and performance tuning in Azure SQL Database and Azure SQL Managed Instance](https://docs.microsoft.com/en-us/azure/azure-sql/database/monitor-tune-overview)
# - [Kusto Query Language (KQL) overview](https://docs.microsoft.com/en-us/azure/data-explorer/kusto/query/)
# - [Use a Jupyter Notebook and kqlmagic extension to analyze data in Azure Data Explorer](https://docs.microsoft.com/en-us/azure/data-explorer/kqlmagic)
# - [Kusto (KQL) extension for Azure Data Studio (Preview)](https://docs.microsoft.com/en-us/sql/azure-data-studio/extensions/kusto-extension?view=sql-server-ver15)
# - [Azure Monitor Logs extension for Azure Data Studio (Preview)](https://docs.microsoft.com/en-us/sql/azure-data-studio/extensions/azure-monitor-logs-extension?view=sql-server-ver15)

# %% [markdown]
# ## Feedback
#
# [https://sqlb.it/?7095](https://sqlb.it/?7095)
#
# ![](https://ecp.yusercontent.com/mail?url=https%3A%2F%2Fchart.apis.google.com%2Fchart%3Fcht%3Dqr%26chs%3D300x300%26chl%3Dhttps%253a%252f%252fsqlb.it%252f%253f7095&t=1646248951&ymreqid=a91aa688-7341-52f0-1cb3-27000701dc00&sig=2RUjHxQKcXnRLZn3.R1oAw--~D)

# %% [markdown]
# ## Contacts
#
# ![myContacts1.png](attachment:image.png)
